# %%
# Date  25 February 2024.
# Exploring & Analysing Merchant sample data.
# Notes & solution by Mr Akhona Njeje.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = {
    'Amount':[40,100,20,150,7,20,30,50,80,40],
    'Merchant Revenue':[70,30,100,25,20,80,150,200,210,75],
    'Merchant Costs':[11,12,10,10,14,7,8,4,15,10],
    'Profit':[60,18,90,15,6,70,100,180,170,60]
}

data1 = {
    'Status':['error', 'app', 'decline', 'app','app','app','error', 'decline', 'app', 'decline'],
    'Amount':[40,100,20,150,7,20,30,50,80,40],
    'Card Brand':['visa', 'master', 'master', 'master', 'master', 'master', 'visa', 'visa', 'visa', 'master'],
    'Merchant Revenue':[70,30,100,25,20,80,150,200,210,75],
    'Bin Copuntry':['Finland', 'Finland', 'Finland', 'Finland', 'Germany','South Africa', 'Kenya', 'Japan', 'Egypt', 'Germany'],
    'Merchant Costs':[11,12,10,10,14,7,8,4,15,10],
    'Profit':[60,18,90,15,6,70,100,180,170,60]
}

Merchant_Dataset = pd.DataFrame(data)
Merchant = pd.DataFrame(data1)
Merchant
# Out:
#     Status  Amount Card Brand  Merchant Revenue  Bin Copuntry  Merchant Costs  \
# 0    error      40       visa                70       Finland              11
# 1      app     100     master                30       Finland              12
# 2  decline      20     master               100       Finland              10
# 3      app     150     master                25       Finland              10
# 4      app       7     master                20       Germany              14
# 5      app      20     master                80  South Africa               7
# 6    error      30       visa               150         Kenya               8
# 7  decline      50       visa               200         Japan               4
# 8      app      80       visa               210         Egypt              15
# 9  decline      40     master                75       Germany              10
#
#    Profit
# 0      60
# 1      18
# 2      90
# 3      15
# 4       6
# 5      70
# 6     100
# 7     180
# ...

# %%
# Line Graph.

Merchant_Dataset.plot()
# Out:
# <Axes: >

# %%
# Scatter plot.

Merchant_Dataset.plot(kind='scatter', x = 'Merchant Revenue', y = 'Merchant Costs')
# Out:
# <Axes: xlabel='Merchant Revenue', ylabel='Merchant Costs'>

# %%
Merchant_Dataset.plot.scatter( x = 'Merchant Revenue', y = 'Merchant Costs')
# Out:
# <Axes: xlabel='Merchant Revenue', ylabel='Merchant Costs'>

# %%
# Histogram.

Merchant_Dataset.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Area Plot.

Merchant_Dataset.plot.area()
# Out:
# <Axes: >

# %%
Merchant_Dataset.plot.bar()
# Out:
# <Axes: >

# %%
# Stacked Bar.

Merchant_Dataset.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
# Horizantal bar.

Merchant_Dataset.plot.barh()
# Out:
# <Axes: >

# %%
# Boxplot.

Merchant_Dataset.plot.box()
# Out:
# <Axes: >

# %%
# Hexagonal Heatmap.

Merchant_Dataset.plot.hexbin( x = 'Merchant Revenue', y = 'Merchant Costs', gridsize=18)
# Out:
# <Axes: xlabel='Merchant Revenue', ylabel='Merchant Costs'>

# %%
# Histogram plot.

Merchant_Dataset.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Density estimate plot.

Merchant_Dataset.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
# Pie Plot.

Merchant_Dataset.plot.pie(y='Profit')
# Out:
# <Axes: ylabel='Profit'>

# %%
# To be continued...
